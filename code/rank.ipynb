# %%
import numpy as np
import pandas as pd
import os
import csv
os.getcwd()
# Out:
# '/Users/wangqiaoyu/Desktop/UW-Madion /628/Module3'

# %%
attribute = pd.read_csv('./data/attr_withtopic.csv')

# %%
attribute['topicindex'][0]==4
# Out:
# True

# %%
index1=[]
index2=[]
index3=[]
index4=[]
index5=[]
for i in range(len(attribute)):
    if attribute['topicindex'][i] == 1:
        index1.append(i)
    elif attribute['topicindex'][i] == 2:
        index2.append(i)
    elif attribute['topicindex'][i] == 3:
        index3.append(i)
    elif attribute['topicindex'][i] == 4:
        index4.append(i)
    else:
        index5.append(i)

# %%
for i in range(len(attribute)):
    attribute['freq'][i]=eval(attribute['freq'][i])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
keylist1=[]
valuelist1=[]
for i in index1:
    for j in range(len(attribute['freq'][i].keys())):
        if list(attribute['freq'][i].keys())[j] not in keylist1:
            keylist1.append(list(attribute['freq'][i].keys())[j])
            valuelist1.append(list(attribute['freq'][i].values())[j])
        else:
            valuelist1[keylist1.index(list(attribute['freq'][i].keys())[j])]+=list(attribute['freq'][i].values())[j]

# %%
dictionary1 = dict(zip(keylist1, valuelist1))
len(keylist1)  #Number of word in topic1.
# Out:
# 30582

# %%
keylist2=[]
valuelist2=[]
for i in index2:
    for j in range(len(attribute['freq'][i].keys())):
        if list(attribute['freq'][i].keys())[j] not in keylist2:
            keylist2.append(list(attribute['freq'][i].keys())[j])
            valuelist2.append(list(attribute['freq'][i].values())[j])
        else:
            valuelist2[keylist2.index(list(attribute['freq'][i].keys())[j])]+=list(attribute['freq'][i].values())[j]

# %%
dictionary2 = dict(zip(keylist2, valuelist2))
len(keylist2)  #Number of word in topic2.
# Out:
# 46738

# %%
keylist3=[]
valuelist3=[]
for i in index3:
    for j in range(len(attribute['freq'][i].keys())):
        if list(attribute['freq'][i].keys())[j] not in keylist3:
            keylist3.append(list(attribute['freq'][i].keys())[j])
            valuelist3.append(list(attribute['freq'][i].values())[j])
        else:
            valuelist3[keylist3.index(list(attribute['freq'][i].keys())[j])]+=list(attribute['freq'][i].values())[j]

# %%
dictionary3 = dict(zip(keylist3, valuelist3))
len(keylist3)  #Number of word in topic3.
# Out:
# 20964

# %%
keylist4=[]
valuelist4=[]
for i in index4:
    for j in range(len(attribute['freq'][i].keys())):
        if list(attribute['freq'][i].keys())[j] not in keylist4:
            keylist4.append(list(attribute['freq'][i].keys())[j])
            valuelist4.append(list(attribute['freq'][i].values())[j])
        else:
            valuelist4[keylist4.index(list(attribute['freq'][i].keys())[j])]+=list(attribute['freq'][i].values())[j]

# %%
dictionary4 = dict(zip(keylist4, valuelist4))
len(keylist4)  #Number of word in topic4.
# Out:
# 27321

# %%
keylist5=[]
valuelist5=[]
for i in index5:
    for j in range(len(attribute['freq'][i].keys())):
        if list(attribute['freq'][i].keys())[j] not in keylist5:
            keylist5.append(list(attribute['freq'][i].keys())[j])
            valuelist5.append(list(attribute['freq'][i].values())[j])
        else:
            valuelist5[keylist5.index(list(attribute['freq'][i].keys())[j])]+=list(attribute['freq'][i].values())[j]

# %%
dictionary5 = dict(zip(keylist5, valuelist5))
len(keylist5)  #Number of word in topic5.
# Out:
# 33617

# %%
sortlist1=sorted(dictionary1.items(), key=lambda d: d[1],reverse=True)
sortlist2=sorted(dictionary2.items(), key=lambda d: d[1],reverse=True)
sortlist3=sorted(dictionary3.items(), key=lambda d: d[1],reverse=True)
sortlist4=sorted(dictionary4.items(), key=lambda d: d[1],reverse=True)
sortlist5=sorted(dictionary5.items(), key=lambda d: d[1],reverse=True)

# %%
sortlist1[:10]
# Out:
# [('place', 50188.92273585015),
#  ('food', 48057.47457722583),
#  ('good', 45120.87058264958),
#  ('sandwich', 38961.558122130715),
#  ('order', 38550.29337281772),
#  ('ame', 36706.47066231584),
#  ('like', 35386.920104451194),
#  ('one', 33458.38339965473),
#  ('get', 33122.080744516876),
#  ('ti', 31931.44512889424)]

# %%
PAreview = []
file = open('./data/PAreview_clean.csv','r', encoding='utf-8',errors='ignore')
myfile = csv.DictReader(file)
for x in myfile:
    line = {'business_id':x['business_id'],'text':x['text']}
    PAreview.append(line)
file.close()

# %%
for i in range(len(PAreview)):
    PAreview[i]['text']=PAreview[i]['text'][:(len(PAreview[i]['text'])-1)]

# %%
#Put all the reviews of a business together
buid=[]
text=[]
for line in PAreview:
    oneid = line["business_id"]
    smalltext = []
    if oneid not in buid:
        buid.append(oneid)
        temp_list = filter(lambda x: x["business_id"] == line["business_id"], PAreview)
        for onelist in temp_list:
            for i in range(len(onelist['text'].split(','))):       
                preword=onelist['text'].split(',')[i]
                word=preword[2:len(preword)-1]
                smalltext.append(word)    
        text.append(smalltext)            
    else:
        continue

# %%
len(text)
buid_review = dict(zip(buid, text))

# %%
overrate=['place','area','experi','everyth','atmospher','spot']
foodword1=['chees','food','sandwich','breakfast','coffe','meat','chicken','salad','bread','lunch','egg','drink','side','burger','sauc','meal','diner','flavor','steak','potato','bar','beef','toast','bacon','beer','sausag']
foodword2=['food','sandwich','breakfast','chicken','bread','lunch','drink','side','burger','sauc','meal','diner','flavor','steak','potato','bar','beef','onion','toast','bacon','beer','sausag','ingredi','wine','dessert','cocktail','pork','brunch','wing','soup']
foodword3=['cream','cupcak','sugar','milk','waffl','food','tea','bakeri','sandwich','breakfast','coffe','bread','lunch','drink','side','sauc','meal','diner','flavor','bar','beef','toast','beer','sausag']
foodword4=['garlic','pepper','soup','pepperoni','pie','meatbal','pasta','chees','pizza','food','sandwich','breakfast','coffe','drink','side','burger','sauc','meal','diner','flavor','potato','bar','beef','toast','bacon','beer','sausag','wing']
foodword5=['roll','noodl','thai','sushi','rice','taco','tofu','veggi','soup','egg','food','pork','chip','shri','sandwich','breakfast','coffe','meat','lunch','fish','drink','side','salsa','tea','burger','sauc','meal','diner','steak','potato','bar','beef','beer']
#waitword=['wait','waitress','NOTwait']
#delivery4=['deliveri']
serviceword=['servic','staff','serv','wait','waitress','NOTwait']
priceword=['price']
adjword=['good','best','great','well','nice','fresh','delici','pertti','better','small','perfect','top','amaz','quick','big','recommend','new','favorit','long','tasti','high','special','kind','awesom','clean','bad','old','huge','larg','worth','ok','free','NOTgood','happi','regular','least','NOTmuch','cool','disappoint','warm','plenti','deli','less','surpris','NOTbad','basic','serious','pleasant','fantast','complet','pleas','fine','crowd','origin','soft','slow','fun','spici','okay','averag','beauti','wrong','hate','easi','sweet']

# %%
bu_id1=list(attribute['business_id'][index1])
bu_id2=list(attribute['business_id'][index2])
bu_id3=list(attribute['business_id'][index3])
bu_id4=list(attribute['business_id'][index4])
bu_id5=list(attribute['business_id'][index5])

# %%
business=pd.read_csv('./data/PA_business_cleaning.csv')

# %%
bigkeylist1=list(bu_id1)
bigvaluelist1=[]
for oneid in bu_id1:
    mediumkeylist1=['topic','stars','overrate','food','service','price']
    mediumvaluelist1=[1]
    starindex=list(business['business_id']).index(oneid)
    mediumvaluelist1.append(business['stars'][starindex])
    smallkeylist1=adjword
    smallvaluelist1=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist1[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist1[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist1[i]+=1
    smalldic1=dict(zip(smallkeylist1, smallvaluelist1))   
    mediumvaluelist1.append(smalldic1)   
    
    smallvaluelist1=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in foodword1:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in foodword1:
                        smallvaluelist1[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in foodword1:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in foodword1:
                        smallvaluelist1[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in foodword1:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in foodword1:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-1] in foodword1:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in foodword1:
                        smallvaluelist1[i]+=1
    smalldic1=dict(zip(smallkeylist1, smallvaluelist1))   
    mediumvaluelist1.append(smalldic1)   
    
    smallvaluelist1=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist1[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist1[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist1[i]+=1
    smalldic1=dict(zip(smallkeylist1, smallvaluelist1))   
    mediumvaluelist1.append(smalldic1)     
    
    smallvaluelist1=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist1[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist1[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist1[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist1[i]+=1
    smalldic1=dict(zip(smallkeylist1, smallvaluelist1))   
    mediumvaluelist1.append(smalldic1)   
    
    mediumdic1=dict(zip(mediumkeylist1, mediumvaluelist1)) 
    bigvaluelist1.append(mediumdic1)    
wholedic1=dict(zip(bigkeylist1, bigvaluelist1))

# %%
bigkeylist2=list(bu_id2)
bigvaluelist2=[]
for oneid in bu_id2:
    mediumkeylist2=['topic','stars','overrate','food','service','price']
    mediumvaluelist2=[2]
    starindex=list(business['business_id']).index(oneid)
    mediumvaluelist2.append(business['stars'][starindex])
    smallkeylist2=adjword
    smallvaluelist2=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist2[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist2[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist2[i]+=1
    smalldic2=dict(zip(smallkeylist2, smallvaluelist2))   
    mediumvaluelist2.append(smalldic2)   
    
    smallvaluelist2=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in foodword2:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in foodword2:
                        smallvaluelist2[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in foodword2:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in foodword2:
                        smallvaluelist2[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in foodword2:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in foodword2:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-1] in foodword2:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in foodword2:
                        smallvaluelist2[i]+=1
    smalldic2=dict(zip(smallkeylist2, smallvaluelist2))   
    mediumvaluelist2.append(smalldic2)   
    
    smallvaluelist2=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist2[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist2[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist2[i]+=1
    smalldic2=dict(zip(smallkeylist2, smallvaluelist2))   
    mediumvaluelist2.append(smalldic2)     
    
    smallvaluelist2=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist2[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist2[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist2[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist2[i]+=1
    smalldic2=dict(zip(smallkeylist2, smallvaluelist2))   
    mediumvaluelist2.append(smalldic2)   
    
    mediumdic2=dict(zip(mediumkeylist2, mediumvaluelist2)) 
    bigvaluelist2.append(mediumdic2)    
wholedic2=dict(zip(bigkeylist2, bigvaluelist2))

# %%
bigkeylist3=list(bu_id3)
bigvaluelist3=[]
for oneid in bu_id3:
    mediumkeylist3=['topic','stars','overrate','food','service','price']
    mediumvaluelist3=[3]
    starindex=list(business['business_id']).index(oneid)
    mediumvaluelist3.append(business['stars'][starindex])
    smallkeylist3=adjword
    smallvaluelist3=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist3[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist3[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist3[i]+=1
    smalldic3=dict(zip(smallkeylist3, smallvaluelist3))   
    mediumvaluelist3.append(smalldic3)   
    
    smallvaluelist3=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in foodword3:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in foodword3:
                        smallvaluelist3[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in foodword3:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in foodword3:
                        smallvaluelist3[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in foodword3:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in foodword3:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-1] in foodword3:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in foodword3:
                        smallvaluelist3[i]+=1
    smalldic3=dict(zip(smallkeylist3, smallvaluelist3))   
    mediumvaluelist3.append(smalldic3)   
    
    smallvaluelist3=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist3[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist3[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist3[i]+=1
    smalldic3=dict(zip(smallkeylist3, smallvaluelist3))   
    mediumvaluelist3.append(smalldic3)     
    
    smallvaluelist3=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist3[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist3[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist3[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist3[i]+=1
    smalldic3=dict(zip(smallkeylist3, smallvaluelist3))   
    mediumvaluelist3.append(smalldic3)   
    
    mediumdic3=dict(zip(mediumkeylist3, mediumvaluelist3)) 
    bigvaluelist3.append(mediumdic3)    
wholedic3=dict(zip(bigkeylist3, bigvaluelist3))

# %%
bigkeylist4=list(bu_id4)
bigvaluelist4=[]
for oneid in bu_id4:
    mediumkeylist4=['topic','stars','overrate','food','service','price']
    mediumvaluelist4=[4]
    starindex=list(business['business_id']).index(oneid)
    mediumvaluelist4.append(business['stars'][starindex])
    smallkeylist4=adjword
    smallvaluelist4=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist4[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist4[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist4[i]+=1
    smalldic4=dict(zip(smallkeylist4, smallvaluelist4))   
    mediumvaluelist4.append(smalldic4)   
    
    smallvaluelist4=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in foodword4:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in foodword4:
                        smallvaluelist4[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in foodword4:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in foodword4:
                        smallvaluelist4[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in foodword4:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in foodword4:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-1] in foodword4:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in foodword4:
                        smallvaluelist4[i]+=1
    smalldic4=dict(zip(smallkeylist4, smallvaluelist4))   
    mediumvaluelist4.append(smalldic4)   
    
    smallvaluelist4=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist4[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist4[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist4[i]+=1
    smalldic4=dict(zip(smallkeylist4, smallvaluelist4))   
    mediumvaluelist4.append(smalldic4)     
    
    smallvaluelist4=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist4[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist4[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist4[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist4[i]+=1
    smalldic4=dict(zip(smallkeylist4, smallvaluelist4))   
    mediumvaluelist4.append(smalldic4)   
    
    mediumdic4=dict(zip(mediumkeylist4, mediumvaluelist4)) 
    bigvaluelist4.append(mediumdic4)    
wholedic4=dict(zip(bigkeylist4, bigvaluelist4))

# %%
bigkeylist5=list(bu_id5)
bigvaluelist5=[]
for oneid in bu_id5:
    mediumkeylist5=['topic','stars','overrate','food','service','price']
    mediumvaluelist5=[5]
    starindex=list(business['business_id']).index(oneid)
    mediumvaluelist5.append(business['stars'][starindex])
    smallkeylist5=adjword
    smallvaluelist5=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist5[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist5[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in overrate:
                     smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in overrate:
                     smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-1] in overrate:
                     smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in overrate:
                     smallvaluelist5[i]+=1
    smalldic5=dict(zip(smallkeylist5, smallvaluelist5))   
    mediumvaluelist5.append(smalldic5)   
    
    smallvaluelist5=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in foodword5:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in foodword5:
                        smallvaluelist5[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in foodword5:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in foodword5:
                        smallvaluelist5[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in foodword5:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in foodword5:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-1] in foodword5:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in foodword5:
                        smallvaluelist5[i]+=1
    smalldic5=dict(zip(smallkeylist5, smallvaluelist5))   
    mediumvaluelist5.append(smalldic5)   
    
    smallvaluelist5=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist5[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist5[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in serviceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in serviceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-1] in serviceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in serviceword:
                        smallvaluelist5[i]+=1
    smalldic5=dict(zip(smallkeylist5, smallvaluelist5))   
    mediumvaluelist5.append(smalldic5)     
    
    smallvaluelist5=[0]*len(adjword)
    for i in range(len(adjword)):
        wordindex=[k for k,v in enumerate(buid_review[oneid]) if v==adjword[i]]
        for oneindex in wordindex:
            if oneindex<2:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist5[i]+=1
            elif oneindex>(len(buid_review[oneid])-3):
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist5[i]+=1
            else:
                if buid_review[oneid][oneindex+1] in priceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex+2] in priceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-1] in priceword:
                        smallvaluelist5[i]+=1
                if buid_review[oneid][oneindex-2] in priceword:
                        smallvaluelist5[i]+=1
    smalldic5=dict(zip(smallkeylist5, smallvaluelist5))   
    mediumvaluelist5.append(smalldic5)   
    
    mediumdic5=dict(zip(mediumkeylist5, mediumvaluelist5)) 
    bigvaluelist5.append(mediumdic5)    
wholedic5=dict(zip(bigkeylist5, bigvaluelist5))

# %%
allkey=bigkeylist1+bigkeylist2+bigkeylist3+bigkeylist4+bigkeylist5
allvalue=bigvaluelist1+bigvaluelist2+bigvaluelist3+bigvaluelist4+bigvaluelist5
alldic=dict(zip(allkey, allvalue))

# %%
df=pd.DataFrame.from_dict(alldic)
df=df.T

# %%
df
# Out:
#                        topic stars  \
# --ujyvoQlwVoBgMYtADiLA     1   3.5
# -1xCh7Cocn6IwFzhELyohA     1   2.5
# -382X_bWhJKPJKP1VfXOmw     1     2
# -7teXSpi9nqy58WUd-8yfw     1   4.5
# -8F04F54iDT6VgWPCgybug     1   4.5
# ...                      ...   ...
# zZ7KDK3GAkBUZzsaqB1A4Q     5     4
# z_DGwPyUPgCk5Q7-WunsbA     5   4.5
# zi6cB_bkswWPLD2k3IVtyg     5   3.5
# zkW7OAv8Cnb-3SxEBOubTQ     5     4
# zxSfGIhK3hH3vVz_pS5eaA     5     3
#
#                                                                  overrate  \
# --ujyvoQlwVoBgMYtADiLA  {'good': 4, 'best': 0, 'great': 11, 'well': 0,...
# -1xCh7Cocn6IwFzhELyohA  {'good': 7, 'best': 0, 'great': 3, 'well': 0, ...
# -382X_bWhJKPJKP1VfXOmw  {'good': 0, 'best': 0, 'great': 0, 'well': 1, ...
# -7teXSpi9nqy58WUd-8yfw  {'good': 2, 'best': 0, 'great': 0, 'well': 0, ...
# -8F04F54iDT6VgWPCgybug  {'good': 6, 'best': 1, 'great': 25, 'well': 4,...
# ...                                                                   ...
# ...

# %%
df.to_csv('/Users/wangqiaoyu/Desktop/UW-Madion /628/Module3/data/rank.csv')

# %%
df.shape
# Out:
# (4524, 6)
